# %% [markdown]
# <a href="https://colab.research.google.com/github/adam18000878/GPTAssessment1/blob/main/GPTAssessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 53.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00

# %%
! pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.28.0

# %%
pip install diffusers --upgrade
# Out:
# Collecting diffusers
#   Downloading diffusers-0.21.2.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (6.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.12.2)
# Collecting huggingface-hub>=0.13.2 (from diffusers)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.31.0)
# Collecting safetensors>=0.3.1 (from diffusers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (9.4.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (23.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2023.7.22)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.21.2-py3-none-any.whl size=1489250 sha256=a7f83dad06111f8c389d6226315301f37d2fb3f522a1b73c26c73e8df478c119
#   Stored in directory: /root/.cache/pip/wheels/2e/09/32/11c9e42c397d3f3494226b28ba68c4ad4718a68a65dba14ea6
# Successfully built diffusers
# Installing collected packages: safetensors, huggingface-hub, diffusers
# Successfully installed diffusers-0.21.2 huggingface-hub-0.17.2 safetensors-0.3.3

# %%
pip install invisible_watermark transformers accelerate safetensors
# Out:
# Collecting invisible_watermark
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.2 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 32.7 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.3.3)
# Requirement already satisfied: Pillow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from invisible_watermark) (9.4.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from invisible_watermark) (1.4.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from invisible_watermark) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from invisible_watermark) (4.8.0.76)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from invisible_watermark) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->invisible_watermark) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->invisible_watermark) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->invisible_watermark) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->invisible_watermark) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->invisible_watermark) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->invisible_watermark) (16.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->invisible_watermark) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->invisible_watermark) (1.3.0)
# Installing collected packages: tokenizers, transformers, invisible_watermark, accelerate
# Successfully installed accelerate-0.23.0 invisible_watermark-0.2.0 tokenizers-0.13.3 transformers-4.33.2

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.1+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)

# %%
pip install stqdm
# Out:
# Collecting stqdm
#   Downloading stqdm-0.0.5-py3-none-any.whl (11 kB)
# Requirement already satisfied: streamlit>=0.66 in /usr/local/lib/python3.10/dist-packages (from stqdm) (1.27.0)
# Requirement already satisfied: tqdm>=4.50 in /usr/local/lib/python3.10/dist-packages (from stqdm) (4.66.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit>=0.66->stqdm) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (1.23.5)
# Requirement already satisfied: packaging<24,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (1.5.3)
# Requirement already satisfied: pillow<10,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (9.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (13.5.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (4.5.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (5.0.1)
# Requirement already satisfied: validators<1,>=0.2 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit>=0.66->stqdm) (3.0.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit>=0.66->stqdm) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit>=0.66->stqdm) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit>=0.66->stqdm) (4.19.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit>=0.66->stqdm) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.66->stqdm) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7,>=1.4->streamlit>=0.66->stqdm) (3.16.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit>=0.66->stqdm) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3,>=2.7.3->streamlit>=0.66->stqdm) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.18->streamlit>=0.66->stqdm) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.18->streamlit>=0.66->stqdm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.18->streamlit>=0.66->stqdm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.18->streamlit>=0.66->stqdm) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit>=0.66->stqdm) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit>=0.66->stqdm) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.66->stqdm) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit>=0.66->stqdm) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.66->stqdm) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.66->stqdm) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.66->stqdm) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.66->stqdm) (0.10.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=0.66->stqdm) (0.1.2)
# Installing collected packages: stqdm
# Successfully installed stqdm-0.0.5

# %%
# %%writefile app.py
import time
import openai
import torch
import streamlit as st
from stqdm import stqdm
from diffusers import DiffusionPipeline

#Stable Diffusion XL setup
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0",
                                         torch_dtype=torch.float16,
                                         use_safetensors=True,
                                         variant="fp16")
pipe.to("cuda")

st.set_page_config(
    page_title="ChemAI",
)

with st.sidebar:
  with st.form("API KEY"):
    openai_api_key = st.text_input("OpenAI API key", value="", type="password")
    st.caption("*If you don't have an OpenAI API key, get it [here](https://platform.openai.com/account/api-keys).*")
    submitted_key = st.form_submit_button('Submit')



if submitted_key:
  try:
      openai.api_key = openai_api_key
      response = openai.Completion.create(engine="davinci", prompt="test")
  except Exception as e:
      st.warning(f'Invalid OpenAI API key: {e}')


#%%
#GPT-3.5-Paramters
#(A) Element Generator
element_gen = """
Generate a short summary for any element. This AI will output The name of an element,
The chemical symbol of an element,The atomic number of an element,The electron configuration of an element
The properties of an element, such as its atomic mass, density, and melting and boiling points depends on the user request.
This chat able to create summary of any elements in periodic table.
"""

Element_user1 = """
Can you give me a summary of oxygen?
"""

Element_response1 = """
Oxygen is Earth's most abundant element, and after hydrogen and helium,
it is the third-most abundant element in the universe. At standard temperature and pressure,
two atoms of the element bind to form dioxygen, a colorless and odorless diatomic gas with the formula O. 2.
"""

element_user2 = """
Can you give me a summary of neon?
"""

element_response2 = """
Neon is a chemical element with the symbol Ne and atomic number 10. It is a noble gas. Neon is a colorless, odorless, inert monatomic gas under standard conditions, with about two-thirds the density of air.
It was discovered (along with krypton and xenon) in 1898 as one of the three residual rare inert elements remaining in dry air, after nitrogen, oxygen, argon and carbon dioxide were removed.
Neon was the second of these three rare gases to be discovered and was immediately recognized as a new element from its bright red emission spectrum.
The name neon is derived from the Greek word, νέον, neuter singular form of νέος (neos), meaning 'new'.
Neon is chemically inert, and no uncharged neon compounds are known. The compounds of neon currently known include ionic molecules, molecules held together by van der Waals forces and clathrates.
"""

element_user3 = """
Can you give me the boiling points of iron?
"""

element_response3 = """
Iron has a Boiling Point of 2861°C, meaning at 2861°C it will turn to a Gas.
"""

#(C) Image Description Generator
idg_system = """
On this section, the image of the element will be output.
"""
idg_input1 = """
give me a short clear image description about the game
"""

idg_response1 = """
Iron is a lustrous, ductile, malleable, silver-gray metal (group VIII of the periodic table).
It is known to exist in four distinct crystalline forms. Iron rusts in damp air, but not in dry air. It dissolves readily in dilute acids.
"""



  #%%

def element_ai(text_input):
    response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {
            "role":"system",
            "content": element_gen
        },

        {
            "role":"user",
            "content" : Element_user1
        },

        {
            "role":"assistant",
            "content": Element_response1
        },

        {
            "role":"user",
            "content" : element_user2
        },

        {
            "role":"assistant",
            "content": element_response2
        },

        {
            "role":"user",
            "content" : element_user3
        },

        {
            "role":"assistant",
            "content": element_response3
        },

        {
            "role":"user",
            "content" : text_input
        }
        ],
    max_tokens = 1000,
    temperature = 1
    )

    elementer = response['choices'][0]['message']['content']
    return elementer

def img_desc(elementer):

    response_img = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {
            "role":"system",
            "content": idg_system
        },

        {
            "role":"user",
            "content" : idg_input1
        },

        {
            "role":"assistant",
            "content": idg_response1
        },

        {
    "role":"user",
    "content" : f"""
    Generate a short clear image description in one sentence about how
    the element look likes: {elementer}.
    The output must be compact in on sentence only.
    """
    }
    ],
    max_tokens = 1000,
    temperature = 1
    )

    img_desc = response_img['choices'][0]['message']['content']
    return img_desc

def stable_diffusion_xl(img_desc):
    prompt = f"""
    Generate a visual image about the element:
    {img_desc}
                      """
    images = pipe(prompt=prompt).images[0]
    return images


#%%
# Setup Streamlit App
# Define custom styles for justified text
justified_text_style = '''
<style>
.justified-text {
    text-align: justify;
}
</style>
'''
st.markdown(justified_text_style, unsafe_allow_html=True)

info = """
I am ChemAI who is your chemistry assistant which able to help with your homework and your questions specifically about periodic table.
Ask me anything about elements in the periodic table and I will summarize the elements and give the picture of it.
It also allows you to generate an image of the elements by using Stable Diffusion XL.
"""

st.markdown("<h1 style='text-align: center; color: white;'>ChemAI</h1>", unsafe_allow_html=True)
col1, col2 = st.columns([5,5])

col1.markdown(f'<div class="justified-text">{info}</div>', unsafe_allow_html=True)

form = col2.form

with form('input_form'):
      text_input = st.text_area("Input your question here")

      submitted = st.form_submit_button('Submit')

      text_inputs = [text_input]

if submitted:


    for i in stqdm(range(100), backend=True, frontend=True):
      time.sleep(0.5)

    element = element_ai(text_input)
    st.markdown('**_Output:_** ')
    st.write(element)

    image_desc = img_desc(element)
    st.markdown('**_The Image Description:_** ')
    st.write(image_desc)
    for i in stqdm(range(100), backend=True, frontend=True):
      time.sleep(0.5)
    st.markdown('**_Predicted image that generated by AI:_** ')
    image = stable_diffusion_xl(image_desc)
    st.image(image)
# Out:
# Writing app.py

# %%
print("############")
print("IP v")
# !curl https://ipv4.icanhazip.com/
print("############")
# Out:
# ############
# IP v
# 34.127.80.214
# ############

# %%
# !streamlit run app.py & npx localtunnel -p 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.127.80.214:8501
#
# npx: installed 22 in 3.382s
# your url is: https://clear-buckets-drive.loca.lt
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-09-24 20:47:31.327665: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading (…)ain/model_index.json: 100% 609/609 [00:00<00:00, 3.33MB/s]
# Fetching 19 files:   0% 0/19 [00:00<?, ?it/s]
# Downloading (…)tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 3.20MB/s]
#
#
# Downloading (…)_encoder/config.json: 100% 565/565 [00:00<00:00, 2.99MB/s]
#
#
# Downloading (…)cheduler_config.json: 100% 479/479 [00:00<00:00, 2.98MB/s]
# Fetching 19 files:  11% 2/19 [00:00<00:07,  2.42it/s]
#
# Downloading (…)okenizer_config.json: 100% 737/737 [00:00<00:00, 4.40MB/s]
#
#
# Downloading (…)ncoder_2/config.json: 100% 575/575 [00:00<00:00, 3.85MB/s]
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 7.00MB/s]
#
# Downloading model.fp16.safetensors:   0% 0.00/246M [00:00<?, ?B/s]
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   0% 0.00/1.39G [00:00<?, ?B/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100% 460/460 [00:00<00:00, 2.40MB/s]
#
#
#
#
# Downloading (…)okenizer_config.json: 100% 725/725 [00:00<00:00, 2.23MB/s]
#
#
#
#
# Downloading (…)76f/unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 6.80MB/s]
#
# Downloading model.fp16.safetensors:   4% 10.5M/246M [00:00<00:02, 96.8MB/s]
#
#
# Downloading model.fp16.safetensors:   2% 21.0M/1.39G [00:00<00:08, 164MB/s]
#
#
#
# Downloading (…)d76f/vae/config.json: 100% 642/642 [00:00<00:00, 2.32MB/s]
#
# Downloading model.fp16.safetensors:  13% 31.5M/246M [00:00<00:01, 121MB/s]
#
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 4.02MB/s]
#
#
#
# Downloading model.fp16.safetensors:   4% 52.4M/1.39G [00:00<00:06, 199MB/s]
# Downloading model.fp16.safetensors:  21% 52.4M/246M [00:00<00:01, 139MB/s]
#
#
# Downloading model.fp16.safetensors:   5% 73.4M/1.39G [00:00<00:07, 185MB/s]
#
# Downloading (…)kenizer_2/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:  30% 73.4M/246M [00:00<00:01, 127MB/s]
#
#
# Downloading model.fp16.safetensors:   7% 94.4M/1.39G [00:00<00:08, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 0.00/5.14G [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:  38% 94.4M/246M [00:00<00:01, 130MB/s]
#
#
# Downloading model.fp16.safetensors:   8% 115M/1.39G [00:00<00:08, 146MB/s]
#
# Downloading (…)kenizer_2/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 3.59MB/s]
#
#
# Downloading (…)del.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:  47% 115M/246M [00:00<00:00, 145MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 10.5M/5.14G [00:00<04:25, 19.3MB/s]
#
# Downloading (…)del.fp16.safetensors:   6% 10.5M/167M [00:00<00:08, 19.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 10.5M/167M [00:00<00:08, 19.3MB/s]
#
#
# Downloading model.fp16.safetensors:  10% 136M/1.39G [00:02<00:35, 35.8MB/s]
#
#
# Downloading model.fp16.safetensors:  11% 147M/1.39G [00:03<00:53, 23.3MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 21.0M/5.14G [00:02<12:23, 6.88MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13% 21.0M/167M [00:02<00:20, 7.30MB/s]
#
# Downloading (…)del.fp16.safetensors:  13% 21.0M/167M [00:02<00:20, 7.11MB/s]
#
#
# Downloading model.fp16.safetensors:  12% 168M/1.39G [00:03<00:37, 32.6MB/s]
# Downloading model.fp16.safetensors:  55% 136M/246M [00:03<00:05, 21.1MB/s]
# Downloading model.fp16.safetensors:  60% 147M/246M [00:03<00:04, 24.5MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 31.5M/5.14G [00:03<08:08, 10.4MB/s]
# Downloading model.fp16.safetensors:  64% 157M/246M [00:03<00:03, 27.7MB/s]
#
#
# Downloading model.fp16.safetensors:  13% 178M/1.39G [00:03<00:37, 32.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19% 31.5M/167M [00:02<00:12, 11.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  19% 31.5M/167M [00:03<00:12, 10.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 41.9M/5.14G [00:03<05:35, 15.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25% 41.9M/167M [00:03<00:08, 15.6MB/s]
# Downloading model.fp16.safetensors:  68% 168M/246M [00:04<00:02, 29.7MB/s]
#
#
# Downloading model.fp16.safetensors:  14% 189M/1.39G [00:04<00:36, 33.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  25% 41.9M/167M [00:03<00:08, 15.1MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 52.4M/5.14G [00:03<04:37, 18.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31% 52.4M/167M [00:03<00:05, 19.3MB/s]
#
#
# Downloading model.fp16.safetensors:  14% 199M/1.39G [00:04<00:35, 33.4MB/s]
# Downloading model.fp16.safetensors:  72% 178M/246M [00:04<00:02, 30.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  31% 52.4M/167M [00:03<00:06, 18.6MB/s]
#
#
# Downloading model.fp16.safetensors:  16% 220M/1.39G [00:04<00:23, 49.7MB/s]
# Downloading model.fp16.safetensors:  77% 189M/246M [00:04<00:01, 36.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 62.9M/5.14G [00:03<03:35, 23.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38% 62.9M/167M [00:03<00:04, 24.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  38% 62.9M/167M [00:03<00:04, 23.9MB/s]
# Downloading model.fp16.safetensors:  81% 199M/246M [00:04<00:01, 43.9MB/s]
#
#
# Downloading model.fp16.safetensors:  17% 241M/1.39G [00:04<00:17, 64.9MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 73.4M/5.14G [00:04<02:54, 29.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44% 73.4M/167M [00:03<00:03, 29.6MB/s]
#
# Downloading (…)del.fp16.safetensors:  44% 73.4M/167M [00:04<00:03, 28.6MB/s]
#
#
# Downloading model.fp16.safetensors:  19% 262M/1.39G [00:04<00:15, 72.7MB/s]
# Downloading model.fp16.safetensors:  89% 220M/246M [00:04<00:00, 54.9MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 83.9M/5.14G [00:04<02:40, 31.4MB/s]
# Downloading model.fp16.safetensors:  94% 231M/246M [00:05<00:00, 59.6MB/s]
#
#
# Downloading model.fp16.safetensors:  20% 273M/1.39G [00:05<00:15, 72.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50% 83.9M/167M [00:04<00:02, 32.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  50% 83.9M/167M [00:04<00:02, 31.4MB/s]
#
#
# Downloading model.fp16.safetensors:  20% 283M/1.39G [00:05<00:15, 70.2MB/s]
# Downloading model.fp16.safetensors:  98% 241M/246M [00:05<00:00, 56.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 94.4M/5.14G [00:04<02:28, 33.9MB/s]
#
#
# Downloading model.fp16.safetensors:  21% 294M/1.39G [00:05<00:14, 74.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56% 94.4M/167M [00:04<00:02, 32.8MB/s]
#
# Downloading (…)del.fp16.safetensors:  56% 94.4M/167M [00:04<00:02, 33.5MB/s]
#
#
# Downloading model.fp16.safetensors: 100% 246M/246M [00:05<00:00, 44.5MB/s]
# Fetching 19 files:  21% 4/19 [00:06<00:27,  1.83s/it]
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 105M/5.14G [00:04<02:15, 37.2MB/s]
#
# Downloading (…)del.fp16.safetensors:  63% 105M/167M [00:04<00:01, 35.1MB/s]
#
#
# Downloading model.fp16.safetensors:  23% 315M/1.39G [00:05<00:15, 69.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63% 105M/167M [00:04<00:01, 33.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 115M/5.14G [00:05<02:11, 38.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69% 115M/167M [00:04<00:01, 38.9MB/s]
#
# Downloading (…)del.fp16.safetensors:  69% 115M/167M [00:05<00:01, 39.0MB/s]
#
#
# Downloading model.fp16.safetensors:  24% 336M/1.39G [00:05<00:13, 78.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75% 126M/167M [00:05<00:00, 44.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 126M/5.14G [00:05<02:23, 34.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81% 136M/167M [00:05<00:00, 49.2MB/s]
#
# Downloading (…)del.fp16.safetensors:  75% 126M/167M [00:05<00:01, 36.6MB/s]
#
#
# Downloading model.fp16.safetensors:  25% 346M/1.39G [00:06<00:17, 58.5MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 136M/5.14G [00:05<02:07, 39.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88% 147M/167M [00:05<00:00, 50.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  81% 136M/167M [00:05<00:00, 39.9MB/s]
#
#
# Downloading model.fp16.safetensors:  26% 357M/1.39G [00:06<00:18, 56.0MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 147M/5.14G [00:05<01:51, 44.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94% 157M/167M [00:05<00:00, 52.5MB/s]
#
# Downloading (…)del.fp16.safetensors:  88% 147M/167M [00:05<00:00, 42.2MB/s]
#
#
# Downloading model.fp16.safetensors:  26% 367M/1.39G [00:06<00:19, 52.9MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 157M/5.14G [00:06<01:48, 45.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100% 167M/167M [00:05<00:00, 51.2MB/s]
#
# Downloading (…)del.fp16.safetensors:  94% 157M/167M [00:06<00:00, 43.5MB/s]
#
#
# Downloading model.fp16.safetensors:  27% 377M/1.39G [00:06<00:18, 53.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100% 167M/167M [00:07<00:00, 22.8MB/s]
#
#
#
# Downloading model.fp16.safetensors:  28% 388M/1.39G [00:08<00:51, 19.3MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 178M/5.14G [00:07<04:41, 17.6MB/s]
#
# Downloading (…)del.fp16.safetensors: 100% 167M/167M [00:07<00:00, 16.4MB/s]
#
#
# Downloading (…)del.fp16.safetensors: 100% 167M/167M [00:07<00:00, 21.9MB/s]
#
#
#
# Downloading model.fp16.safetensors:  31% 430M/1.39G [00:08<00:20, 45.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 189M/5.14G [00:07<03:45, 22.0MB/s]
#
#
# Downloading model.fp16.safetensors:  33% 461M/1.39G [00:08<00:12, 71.5MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 199M/5.14G [00:08<03:00, 27.3MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 210M/5.14G [00:08<02:29, 33.0MB/s]
#
#
# Downloading model.fp16.safetensors:  35% 482M/1.39G [00:09<00:12, 70.1MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 220M/5.14G [00:08<02:05, 39.2MB/s]
#
#
# Downloading model.fp16.safetensors:  36% 503M/1.39G [00:09<00:10, 81.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 231M/5.14G [00:08<01:49, 44.7MB/s]
#
#
# Downloading model.fp16.safetensors:  38% 524M/1.39G [00:09<00:08, 97.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 241M/5.14G [00:08<01:40, 48.5MB/s]
#
#
# Downloading model.fp16.safetensors:  39% 545M/1.39G [00:09<00:07, 109MB/s]
#
#
# Downloading model.fp16.safetensors:  41% 566M/1.39G [00:09<00:06, 126MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 252M/5.14G [00:08<01:36, 50.7MB/s]
#
#
# Downloading model.fp16.safetensors:  42% 587M/1.39G [00:09<00:06, 126MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 262M/5.14G [00:09<01:31, 53.0MB/s]
#
#
# Downloading model.fp16.safetensors:  44% 608M/1.39G [00:09<00:05, 139MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 273M/5.14G [00:09<01:28, 55.0MB/s]
#
#
# Downloading model.fp16.safetensors:  46% 640M/1.39G [00:10<00:04, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 283M/5.14G [00:09<01:28, 54.9MB/s]
#
#
# Downloading model.fp16.safetensors:  48% 671M/1.39G [00:10<00:04, 168MB/s]
#
#
# Downloading model.fp16.safetensors:  51% 703M/1.39G [00:10<00:03, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 294M/5.14G [00:09<01:25, 56.7MB/s]
#
#
# Downloading model.fp16.safetensors:  52% 724M/1.39G [00:10<00:03, 187MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 304M/5.14G [00:09<01:23, 58.0MB/s]
#
#
# Downloading model.fp16.safetensors:  54% 744M/1.39G [00:10<00:03, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 315M/5.14G [00:09<01:22, 58.4MB/s]
#
#
# Downloading model.fp16.safetensors:  56% 776M/1.39G [00:10<00:03, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 325M/5.14G [00:10<01:22, 58.7MB/s]
#
#
# Downloading model.fp16.safetensors:  58% 807M/1.39G [00:10<00:02, 194MB/s]
#
#
# Downloading model.fp16.safetensors:  60% 839M/1.39G [00:10<00:02, 205MB/s]
#
#
# Downloading model.fp16.safetensors:  63% 870M/1.39G [00:11<00:02, 221MB/s]
#
#
# Downloading model.fp16.safetensors:  65% 902M/1.39G [00:11<00:02, 227MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7% 336M/5.14G [00:10<01:57, 41.0MB/s]
#
#
# Downloading model.fp16.safetensors:  67% 933M/1.39G [00:11<00:02, 222MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7% 346M/5.14G [00:10<01:46, 45.1MB/s]
#
#
# Downloading model.fp16.safetensors:  69% 965M/1.39G [00:11<00:01, 219MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7% 357M/5.14G [00:10<01:37, 48.9MB/s]
#
#
# Downloading model.fp16.safetensors:  72% 996M/1.39G [00:11<00:01, 220MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   